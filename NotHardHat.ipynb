# %%
# !pip install opendatasets

# %%
import opendatasets as od
import pandas

od.download(
	"https://www.kaggle.com/datasets/muhammetzahitaydn/hardhat-vest-dataset-v3/code")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: shekharashishraj
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/muhammetzahitaydn/hardhat-vest-dataset-v3
# ...
#  13%|█▎        | 567M/4.21G [00:26<02:48, 23.3MB/s]

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolo11n.pt")

# %%
import yaml
dict_file = {'train':'/content/hardhat-vest-dataset-v3/images/test' ,
            'val': '/content/hardhat-vest-dataset-v3/images/val',
            'names' :
             {0: 'helmet',
             1: 'vest',
             2: 'head',
             3: 'person'}}

with open('/content/hardhat-vest-dataset-v3/hard_head.yaml', 'w') as file:
    documents = yaml.dump(dict_file,file,default_flow_style=False)

# %%
model.train(data="/content/hardhat-vest-dataset-v3/hard_head.yaml", epochs=20)
# Out:
# Ultralytics 8.3.75 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
results = model(["/content/hardhat-vest-dataset-v3/images/train/000007.jpg","/content/hardhat-vest-dataset-v3/images/train/000002.jpg","/content/1.jpg"])

for result in results:
    boxes = result.boxes
    masks = result.masks
    keypoints = result.keypoints
    probs = result.probs
    obb = result.obb
    result.show()
    result.save(filename="/content/hardhat-vest-dataset-v3/images/result1.jpg")
# Out:
# 0: 640x640 12 helmets, 5.8ms
# 1: 640x640 2 helmets, 5.8ms
# 2: 640x640 1 helmet, 1 vest, 5.8ms
# Speed: 2.0ms preprocess, 5.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=640x640>
# <PIL.Image.Image image mode=RGB size=640x640>
# <PIL.Image.Image image mode=RGB size=400x400>

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding
# !zip -r /content/runs.zip /content/runs
# Out:
#   adding: content/runs/ (stored 0%)
#   adding: content/runs/detect/ (stored 0%)
#   adding: content/runs/detect/train/ (stored 0%)
#   adding: content/runs/detect/train/weights/ (stored 0%)
#   adding: content/runs/detect/train/args.yaml (deflated 53%)
#   adding: content/runs/detect/train6/ (stored 0%)
#   adding: content/runs/detect/train6/weights/ (stored 0%)
#   adding: content/runs/detect/train6/args.yaml (deflated 53%)
#   adding: content/runs/detect/train11/ (stored 0%)
#   adding: content/runs/detect/train11/weights/ (stored 0%)
#   adding: content/runs/detect/train11/args.yaml (deflated 53%)
#   adding: content/runs/detect/train12/ (stored 0%)
#   adding: content/runs/detect/train12/weights/ (stored 0%)
#   adding: content/runs/detect/train12/args.yaml (deflated 53%)
#   adding: content/runs/detect/train4/ (stored 0%)
#   adding: content/runs/detect/train4/weights/ (stored 0%)
#   adding: content/runs/detect/train4/args.yaml (deflated 53%)
# ...
